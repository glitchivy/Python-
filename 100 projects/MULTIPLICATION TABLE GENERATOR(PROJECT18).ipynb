# %% [markdown]
# ###  MULTIPLICATION TABLE GENERATOR

# %% [markdown]
# 🔹 Features
#
# 1.Generate Table of a Single Number – Enter one number and get its table (default up to 10 or 12).
#
# 2.Generate Tables for a Range of Numbers – Print multiplication tables for all numbers in a given range.
#
# 3.Custom Length Table – Choose how many multiples you want (e.g., up to 20, 50, etc.).
#
# 4.Save Table(s) to File – Export the generated table(s) into a text file.
#
# 5.Display All Generated Tables (History) – Show all tables created in the current session.
#
# 6.Clear History – Remove all previously generated tables from memory.
#
# 7.Exit – Quit the program.

# %%
print("MULTIPLICATION TABLE GENERATOR")
print("1.Generate Table of a Single Number")
print("2.Generate Tables for a Range of Numbers")
print("3.Custom Length Table")
print("4.Save Table(s) to File")
print("5.Display All Generated Tables")
print("6.Clear History")
print("7.Exit")
history=[]
while True:
    choice=int(input("enter the number of the operation you want to perform"))
    if choice==7:
        print("Thank you for using")
        break
    elif choice==1:
        number=int(input("enter the number you want the table for"))
        for i in range(1,11):
            multi=number*i
            table=[f"{number}x{i}={multi}"]
            history.append(table)
            print(table)
    elif choice==3:
        number=int(input("enter the number you want the table for"))
        num=int(input("enter the numbers"))
        for i in range(1,num+1):
            multi=number*i
            table=[f"{number}x{i}={multi}"]
            history.append(table)
            print(table)
    elif choice==2:
        number=int(input("enter the number you want the table for"))
        for j in range(1,number+1):
            print(f"for number {j}")
            for i in range(1,11):
                multi=j*i
                table=[f"{j}x{i}={multi}"]
                history.append(table)
                print(table)
    elif choice == 4:  # Save to file
        if not history:
            print(" No tables generated yet to save.")
        else:
            with open("tables.txt", "w") as f:
                for table in history:
                    f.write("\n".join(table))
                    f.write("\n\n")
            print(" Tables saved to 'tables.txt'")
    elif choice==6:
        history.clear()
        print("History deleted")
    elif choice == 5:  # Show history
        if not history:
            print("No tables generated yet.")
        else:
            for table in history:
                
                print("\n".join(table))
# Out:
# MULTIPLICATION TABLE GENERATOR
# 1.Generate Table of a Single Number
# 2.Generate Tables for a Range of Numbers
# 3.Custom Length Table
# 4.Save Table(s) to File
# 5.Display All Generated Tables
# 6.Clear History
# 7.Exit
# enter the number of the operation you want to perform 5
# No tables generated yet.
# enter the number of the operation you want to perform 2
# enter the number you want the table for 10
# for number 1
# ['1x1=1']
# ['1x2=2']
# ['1x3=3']
# ['1x4=4']
# ['1x5=5']
# ['1x6=6']
# ['1x7=7']
# ['1x8=8']
# ['1x9=9']
# ['1x10=10']
# for number 2
# ['2x1=2']
# ['2x2=4']
# ['2x3=6']
# ['2x4=8']
# ['2x5=10']
# ['2x6=12']
# ['2x7=14']
# ['2x8=16']
# ['2x9=18']
# ['2x10=20']
# for number 3
# ['3x1=3']
# ['3x2=6']
# ['3x3=9']
# ['3x4=12']
# ['3x5=15']
# ['3x6=18']
# ['3x7=21']
# ['3x8=24']
# ['3x9=27']
# ['3x10=30']
# for number 4
# ['4x1=4']
# ['4x2=8']
# ['4x3=12']
# ['4x4=16']
# ['4x5=20']
# ['4x6=24']
# ['4x7=28']
# ['4x8=32']
# ['4x9=36']
# ['4x10=40']
# for number 5
# ...
