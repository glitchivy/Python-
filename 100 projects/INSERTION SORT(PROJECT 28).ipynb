# %% [markdown]
# ### INSERTION SORT

# %% [markdown]
#  Menu Options:
#
# Enter a new array – Input a new list of numbers.
#
# Display current array – Show the current array.
#
# Sort in ascending order – Sort and display with steps.
#
# Sort in descending order – Sort and display with steps.
#
# Search for an element – Find the index of an element in the array.
#
# Find maximum and minimum – Show max and min values.
#
# Insert an element at a position – Add a new element anywhere.
#
# Delete an element – Remove an element by value or index.
#
# Reverse array – Reverse the current array.
#
# Exit – Close the program.

# %%
def insertion_sort(arr,show_steps=True,order="asc"):
    n=len(arr)
    for i in range(1,n):
        key=arr[i]
        j=i-1
        while j>=0 and((order=='asc' and arr[j]>key) or (order=='desc' and arr[j]<key)):
            arr[j+1]=arr[j]
            j-=1 
        arr[j+1]=key 
        if show_steps:
            print(f"Pass{i+1}:{arr}")
    return arr 
def menu():
    arr = []
    while True:
        print("\n=== Insertion Sort Project Menu ===")
        print("1. Enter a new array")
        print("2. Display current array")
        print("3. Sort array in ascending order")
        print("4. Sort array in descending order")
        print("5. Search for an element")
        print("6. Find maximum and minimum")
        print("7. Insert an element at a position")
        print("8. Delete an element")
        print("9. Reverse array")
        print("10. Exit")
        
        choice = int(input("Enter your choice (1-10): "))
        if choice==10:
            print("thank you for using")
            break
        elif choice==1:
            arr=list(map(int,input("ENTER THE ARRAY").split()))
            print("THE LIST IS",arr)
        elif choice==2:
            if arr:
                print("THE LIST IS",arr) 
            else:
                print("THE LIST IS EMPTY")
        elif choice==3:
            insertion_sort(arr,show_steps=True)
            print("The sorted array is:",arr)
        elif choice==4:
            insertion_sort(arr,show_steps=True,order='desc')
            print("The sorted array is:",arr)
        elif choice==5:
            x=int(input("enter the element you want to find"))
            if x in arr:
                print(f"The element {x} is found in {arr.index(x)}")
            else:
                print(f"The number {x} is not found")
        elif choice==6:
             print(f"Maximum: {max(arr)}, Minimum: {min(arr)}")
        elif choice==7:
            x=int(input("enter the element value"))
            postion=int(input(f"Enter the postion you want to input btw 0 and {len(arr)}"))
            if 0<=position<=len(arr):
                arr.insert(position,x)
                print("new array is:",arr)
            else:
                print("INVALID")
        elif choice==8:
            x = int(input("Enter element to delete: "))
            if x in arr:
                arr.remove(x)
                print(f"Array after deletion: {arr}")
            else:
                print("error")
        elif choice==9:
            if arr:
                print("earlier array:",arr)
                arr.reverse()
                print("Now array:",arr)
            else:
                print("LIST IS EMPTY")
            
            

if __name__ == "__main__":
    menu()
# Out:
# === Insertion Sort Project Menu ===
# 1. Enter a new array
# 2. Display current array
# 3. Sort array in ascending order
# 4. Sort array in descending order
# 5. Search for an element
# 6. Find maximum and minimum
# 7. Insert an element at a position
# 8. Delete an element
# 9. Reverse array
# 10. Exit
# Enter your choice (1-10):  1
# ENTER THE ARRAY 12 11 10 22 31
# THE LIST IS [12, 11, 10, 22, 31]
#
# === Insertion Sort Project Menu ===
# 1. Enter a new array
# 2. Display current array
# 3. Sort array in ascending order
# 4. Sort array in descending order
# 5. Search for an element
# 6. Find maximum and minimum
# 7. Insert an element at a position
# 8. Delete an element
# 9. Reverse array
# 10. Exit
# Enter your choice (1-10):  9
# earlier array: [12, 11, 10, 22, 31]
# Now array: [31, 22, 10, 11, 12]
#
# === Insertion Sort Project Menu ===
# 1. Enter a new array
# 2. Display current array
# 3. Sort array in ascending order
# 4. Sort array in descending order
# ...
